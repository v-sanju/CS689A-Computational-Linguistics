# %% [markdown]
# # Question 1

# %% [markdown]
# ## IndicTrans2

# %%
# for reading a file
def read_file(path):
    data_set=[]
    with open(path, 'r', encoding='utf-8') as file:
        file_contents = file.read()
    file_contents = file_contents.split('\n')
    return file_contents

# for writing a data to a file
def write_to_file(file_path, string_list):
    with open(file_path, 'w', encoding='utf-8') as file:
        for string in string_list:
            file.write(string + '\n')  # Write the string followed by a newline character

# %%
# read files of 3 different languages (1 english, 1 mother tongue, 1 any other indic lang)
rand_hin = read_file('/kaggle/input/data-for-indictrans/random_hin_1000.txt')
rand_eng = read_file('/kaggle/input/data-for-indictrans/random_eng_1000.txt')
rand_guj = read_file('/kaggle/input/data-for-indictrans/random_guj_1000.txt')

# %% [markdown]
# ### Setup

# %%
# %%capture
# !git clone https://github.com/AI4Bharat/IndicTrans2.git

# %%
# %%capture
# %cd /content/IndicTrans2/huggingface_interface

# %%
# %%capture
# !python3 -m pip install nltk sacremoses pandas regex mock transformers>=4.33.2 mosestokenizer
# !python3 -c "import nltk; nltk.download('punkt')"
# !python3 -m pip install bitsandbytes scipy accelerate datasets
# !python3 -m pip install sentencepiece

# !git clone https://github.com/VarunGumma/IndicTransTokenizer
# %cd IndicTransTokenizer
# !python3 -m pip install --editable ./
# %cd ..

# %%
import torch
from transformers import AutoModelForSeq2SeqLM, BitsAndBytesConfig
from IndicTransTokenizer import IndicProcessor, IndicTransTokenizer

BATCH_SIZE = 4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
quantization = None

# %%
def initialize_model_and_tokenizer(ckpt_dir, direction, quantization):
    if quantization == "4-bit":
        qconfig = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_compute_dtype=torch.bfloat16,
        )
    elif quantization == "8-bit":
        qconfig = BitsAndBytesConfig(
            load_in_8bit=True,
            bnb_8bit_use_double_quant=True,
            bnb_8bit_compute_dtype=torch.bfloat16,
        )
    else:
        qconfig = None

    tokenizer = IndicTransTokenizer(direction=direction)
    model = AutoModelForSeq2SeqLM.from_pretrained(
        ckpt_dir,
        trust_remote_code=True,
        low_cpu_mem_usage=True,
        quantization_config=qconfig,
    )

    if qconfig == None:
        model = model.to(DEVICE)
        if DEVICE == "cuda":
            model.half()

    model.eval()

    return tokenizer, model


def batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip):
    translations = []
    for i in range(0, len(input_sentences), BATCH_SIZE):
        batch = input_sentences[i : i + BATCH_SIZE]

        # Preprocess the batch and extract entity mappings
        batch = ip.preprocess_batch(batch, src_lang=src_lang, tgt_lang=tgt_lang)

        # Tokenize the batch and generate input encodings
        inputs = tokenizer(
            batch,
            src=True,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=5,
                num_return_sequences=1,
            )

        # Decode the generated tokens into text
        generated_tokens = tokenizer.batch_decode(generated_tokens.detach().cpu().tolist(), src=False)

        # Postprocess the translations, including entity replacement
        translations += ip.postprocess_batch(generated_tokens, lang=tgt_lang)

        del inputs
        torch.cuda.empty_cache()

    return translations

# %% [markdown]
# ### English to Hindi

# %%
en_indic_ckpt_dir = "ai4bharat/indictrans2-en-indic-1B"  # ai4bharat/indictrans2-en-indic-dist-200M
en_indic_tokenizer, en_indic_model = initialize_model_and_tokenizer(en_indic_ckpt_dir, "en-indic", quantization)
ip = IndicProcessor(inference=True)
src_lang, tgt_lang = "eng_Latn", "hin_Deva"
hi_translations = batch_translate(rand_eng, src_lang, tgt_lang, en_indic_model, en_indic_tokenizer, ip)
write_to_file('/kaggle/working/indicTrans_translated_eng_to_hin.txt', hi_translations)
# flush the models to free the GPU memory
del en_indic_tokenizer, en_indic_model

# %% [markdown]
# ### Hindi to English

# %%
indic_en_ckpt_dir = "ai4bharat/indictrans2-indic-en-1B"  # ai4bharat/indictrans2-indic-en-dist-200M
indic_en_tokenizer, indic_en_model = initialize_model_and_tokenizer(indic_en_ckpt_dir, "indic-en", "")

ip = IndicProcessor(inference=True)

src_lang, tgt_lang = "hin_Deva", "eng_Latn"
en_translations = batch_translate(rand_hin, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip)

write_to_file('/kaggle/working/indicTrans_translated_hin_to_eng.txt', en_translations)

# flush the models to free the GPU memory
del indic_en_tokenizer, indic_en_model

# %% [markdown]
# ### Hindi to Gujrati

# %%
indic_indic_ckpt_dir = "ai4bharat/indictrans2-indic-indic-1B"  # ai4bharat/indictrans2-indic-indic-dist-320M
indic_indic_tokenizer, indic_indic_model = initialize_model_and_tokenizer(indic_indic_ckpt_dir, "indic-indic", quantization)

ip = IndicProcessor(inference=True)

src_lang, tgt_lang = "hin_Deva", "guj_Gujr"
guj_translations = batch_translate(rand_hin, src_lang, tgt_lang, indic_indic_model, indic_indic_tokenizer, ip)

write_to_file('/kaggle/working/indicTrans_translated_hin_to_guj.txt', guj_translations)
# flush the models to free the GPU memory
del indic_indic_tokenizer, indic_indic_model

# %% [markdown]
# ### Gujrati to Hindi

# %%
indic_indic_ckpt_dir = "ai4bharat/indictrans2-indic-indic-1B"  # ai4bharat/indictrans2-indic-indic-dist-320M
indic_indic_tokenizer, indic_indic_model = initialize_model_and_tokenizer(indic_indic_ckpt_dir, "indic-indic", quantization)

ip = IndicProcessor(inference=True)

src_lang, tgt_lang =  "guj_Gujr", "hin_Deva"
hin_translations = batch_translate(rand_guj, src_lang, tgt_lang, indic_indic_model, indic_indic_tokenizer, ip)

write_to_file('/kaggle/working/indicTrans_translated_guj_to_hin.txt', hin_translations)
# flush the models to free the GPU memory
del indic_indic_tokenizer, indic_indic_model
# Out:
# config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# configuration_indictrans.py:   0%|          | 0.00/14.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-1B:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py:   0%|          | 0.00/61.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-1B:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]

# %% [markdown]
# ## ChatGPT

# %%
rand_50_eng = rand_eng[:50]
rand_50_hin = rand_hin[:50]
rand_50_guj = rand_guj[:50]

# %%
for i,sent in enumerate(rand_50_eng):
    print(i+1,". ", sent)
# Out:
# 1 .  He will release a document highlighting the achievements of the Government.
# 2 .  I am particularly grateful to Prime Minister Abe for his encouragement and support at a personal level.
# 3 .  In the next two months, we will be busy in the hurly-burly of the general elections.
# 4 .  He said the Union Government has got 5 crore toilets built in three years.
# 5 .  The unique festival Chhath Pooja is deeply linked with nature & worshiping nature.
# 6 .  This Agreement shall enter into force on the first day of the second month after the Contracting Parties notify each other in through diplomatic channels, that the necessary national legal requirements for entry into force of this Agreement have been fulfilled.
# 7 .  I greatly welcome the growing ties between our parliamentarians, and between our states and Japan’s prefectures.
# 8 .  India is now ripe, for a sweet revolution.
# 9 .  The MoU covers the following areas of cooperation:-
# 10 .  The Prime Minister added that these facilities will also attract tourists.
# 11 .  India has jumped 42 places in three years to enter the top hundred in the World Bank’s Ease of Doing Business Report 2018.
# 12 .  On behalf of the people and the farmers of Gujarat and Maharashtra, who benefit from the Narmada, the Prime Minister thanked the people and the Government of Madhya Pradesh, for the Narmada Seva Yatra.
# 13 .  This is the fifth interaction in the series by the Prime Minister through video bridge with various beneficiaries of Government schemes.
# 14 .  Speaking at the event, he said Mahatma Gandhi’s thoughts have the power to mitigate the challenges the world is facing today.
# 15 .  Now they shall be empowered with smartphones and digital devices to provide financial services.
# 16 .  We have to further fortify that legacy.
# 17 .  TheBishnoi community in the desert land of Rajasthan has shown us a way of environment protection.
# 18 .  It seems to become a question of life and death.
# 19 .  It has been made possible because of close cooperation between the Central Government and all the State Governments as well as all political parties.
# 20 .  Uttarakhand and Haryana have also been declared ODF, this week.
# 21 .  He emphasized the importance of positive news for a vibrant and prosperous nation.
# 22 .  SCIENCE AND TECHNOLOGY
# 23 .  In India,as in most emerging economies, our challenge is to grow horizontally as well as vertically.
# 24 .  The country is governed by peace, harmony and unity.
# 25 .  As on date, integration of datasets of 41 programmes and schemes of 20 Ministries has been achieved on this Portal.
# 26 .  The Prime Minister called for speeding up of work related to redevelopment of Railway Stations, and greater creativity in the generation of non-fare revenue.
# 27 .  Japanese people have led the world in sustainable development.
# 28 .  Our players performed magnificently and on the basis of their sterling efforts, India has become the Asia Cup champion after an interval of ten years.
# 29 .  This Rudraksh will be a gar-land of love of Japan for Varanasi.
# 30 .  Usually they were built at a vast area of land, and often away from the residential areas.
# 31 .  He was the first Indian who set on a global voyage in a small boat without any modern technology.
# 32 .  Prime Minister Shri Narendra Modi will attend the Annual Conference of DGPs and IGPs on 7th and 8th January at the BSF Academy at Tekanpur, Madhya Pradesh.
# 33 .  The Prime Minister said that spiritual institutions in India, have been centres for the spread of social reform.
# 34 .  The founding conference of the Alliance was held in New Delhi earlier this year.
# 35 .  He was an effective voice for Karnataka’s aspirations in Delhi.
# 36 .  He added that their efforts have ensured that Indian Passport is respected everywhere.
# 37 .  Luckily I got another chance to celebrate Deepawali with our courageous and brave heart security personnel.
# 38 .  Our trade and investment relations are becoming more and more intense.
# 39 .  A series of Yoga related events are being organized across the world to mark the occasion.
# 40 .  The Prime Minister explained how the Union Government is focused on improving ease of doing business, and ease of living for the citizens.
# 41 .  The requirement of road, rail and waterways is enormous.
# 42 .  During the interaction, the crew made a presentation on various aspects of the mission, their preparation, training, and experiences during the journey.
# 43 .  The setting up of a Chair on the Paika Rebellion, in Utkal University, Bhubaneswar, was announced.
# 44 .  Prime Minister assured him of India’s full and constructive cooperation in discharging his new responsibilities.
# 45 .  He said that it is also a responsibility to be careful and conserve as much water as possible.
# 46 .  With their collective efforts, they have not only changed their own fortunes but have changed fortunes of the whole region.
# 47 .  Through the UMANG App, more than 100 public services have been made available to the citizens through their mobile phone.
# 48 .  This is indeed, a possession that can benefit every spiritual seeker, yogi, and even a common person.
# 49 .  Even today, knowledge is the best guiding light.
# 50 .  The phase being inaugurated today will operate from Aluva to Palarivattom.

# %%
for i,sent in enumerate(rand_50_hin):
    print(i+1,". ", sent)
# Out:
# 1 .  प्रधानमंत्री सरकार की उपलब्धियों को उजागर करने वाला एक दस्‍तावेज जारी करेंगे।
# 2 .  मैं प्रधानमंत्री आबे के प्रति उनके प्रोत्‍साहन और व्‍यक्तिगत स्‍तर पर समर्थन के लिए खास तौर पर आभारी हूं।
# 3 .  अगले दो महीने, हम सभी चुनाव की गहमा-गहमी में व्यस्त होगें।
# 4 .  उन्होंने कहा कि केंद्र सरकार ने पिछले 3 वर्षों में पांच करोड़ शौचालयों का निर्माण किया है।
# 5 .  छठ-पूजा का अनुपम-पर्व प्रकृति से और प्रकृति की उपासना से पूरी तरह जुड़ा हुआ है।
# 6 .  सीमा शुल्‍क मामलों में सहयोग और परस्‍पर सहायता पर भारत गणराज्‍य की सरकार और अर्मेनिया गणराज्‍य की सरकार के बीच करार पर भारत सरकार की ओर से हस्‍ताक्षर किए जाएंगे और यह क‍ि इस करार के लागू होने के लिए आवश्‍यक राष्‍ट्रीय कानूनी अपेक्षाओं को पूरा कर लिया गया है।
# 7 .  मैं अपने सांसदों, अपने राज्यों और जापान के प्रान्तों के बीच बढ़ते रिश्तों का हृदय से स्वागत करता हूँ।
# 8 .  भारत अब एक sweet revolution की ओर बढ़ रहा है।
# 9 .  समझौता-ज्ञापन के दायरे में निम्‍नलिखित सहयोग क्षेत्र है:-
# 10 .  प्रधानमंत्री ने यह भी कहा कि ये सुविधाएं पर्यटकों को भी आकर्षित करेंगी।
# 11 .  भारत पिछले तीन वर्षों के दौरान विश्‍व बैंक की ‘कारोबार में सुगमता’ रिपोर्ट 2018 में 42 पायदान ऊपर चढ़कर शीर्ष 100 पायदान में शामिल हो गया है।
# 12 .  प्रधानमंत्री ने गुजरात और महाराष्‍ट्र की जनता और क‍िसानों की ओर से, जो नर्मदा नदी से लाभान्‍व‍ित होते हैं, नर्मदा सेवा यात्रा के ल‍िए मध्‍यप्रदेश की जनता और सरकार को धन्‍यवाद द‍िया ।
# 13 .  प्रधानमंत्री ने पांचवी बार वीडियो ब्रिज के माध्यम से सरकारी योजनाओं के विभिन्न लाभार्थियों के साथ संवाद स्थापित किया।
# 14 .  इस अवसर पर उन्होंने कहा कि महात्मा गांधी के विचारों में वह शक्ति है जो विश्व में आज की चुनौतियां का समाधान कर सकती है।
# 15 .  अब लोगों को वित्तीय सेवाएं सुलभ कराने के उद्देश्‍य से उन्हें स्मार्टफोन और डिजिटल उपकरणों के माध्‍यम से सशक्त बनाया जाएगा।
# 16 .  इस विरासत को हमें और सशक्त करना है।
# 17 .  राजस्थान जैसी मरुभूमि में बिश्नोई समाज ने पर्यावरण संरक्षण का रास्ता हमें दिखाया है।
# 18 .  ऐसा लगता है कि वो जीवन-मरण का जैसे सवाल है।
# 19 .  यह केंद्र सरकार और राज्य सरकारों के साथ-साथ सभी राजनीतिक दलों के बीच निकट सहयोग के कारण संभव हो पाया है।
# 20 .  इस सप्ताह उत्तराखण्ड और हरियाणा भी ODF घोषित हुए।
# 21 .  उन्‍होंने जीवंत और खुशहाल देश के लिए सकारात्‍मक समाचारों के महत्‍व पर बल दिया।
# 22 .  विज्ञान एवं प्रौद्योगिकी
# 23 .  ज्‍यादातर उभरती अर्थव्‍यवस्‍थाओं की तरह भारत में भी हमारी चुनौती क्षैतिज और लंबवत दोनों ही तरीकों से बढ़ेगी।
# 24 .  देश शांति, सद्भावना और एकता से चलता है।
# 25 .  अभी तक 20 मंत्रालय के 41 कार्यक्रमों व योजनाओं की प्रगति के आंकड़े इस पोर्टल पर दर्शाए गए हैं।
# 26 .  प्रधानमंत्री ने रेलवे स्टेशनों के पुनर्विकास से संबंधित कार्यों को तेज करने और गैर किराया राजस्व के क्षेत्र में रचनात्मक काम करने को कहा।
# 27 .  जापानी लोगों ने सतत विकास के क्षेत्र में दुनिया का नेतृत्व किया है।
# 28 .  हमारे खिलाड़ियों ने बेहतरीन प्रदर्शन किया और इसी के बल पर भारत दस साल बाद एशिया कप champion बना है।
# 29 .  यह रुद्राक्ष वाराणसी के लिए जापान की ओर से स्नेह की माला होगी।
# 30 .  आमतौर पर रिहायशी क्षेत्र से दूर एक विस्‍तृत भूखंड पर मंदिरों का निर्माण किया जाता था।
# 31 .  वे अकेले कोई भी आधुनिक technology बिना की एक छोटी सी नाव ले करके, विश्व भ्रमण करने वाले पहले भारतीय थे।
# 32 .  प्रधानमंत्री श्री नरेन्द्र मोदी 7 व 8 जनवरी को बीएसएफ अकादमी, टेकनपुर, मध्य प्रदेश में पुलिस महानिदेशकों के वार्षिक सम्मेलन में भाग लेंगे।
# 33 .  प्रधानमंत्री ने कहा कि भारत में आध्यात्मिक संस्थान सामाजिक सुधार के प्रसार के केंद्र रहे हैं।
# 34 .  इस गठबंधन का संस्थापना सम्‍मेलन इस वर्ष के आरंभ में नई दिल्‍ली में आयोजित किया गया।
# 35 .  वह दिल्ली में कर्नाटक की आकांक्षाओं के एक प्रभावी आवाज थे।
# 36 .  उन्होंने कहा कि प्रवासी भारतीयों के प्रयास से सभी जगह भारतीय पासपोर्ट के प्रति सम्मान सुनिश्चित हुआ है।
# 37 .  मुझे एक बार फिर सीमा पर तैनात हमारे जाबांज़ सुरक्षाबलों के साथ दीपावली मनाने का सौभाग्य मिला।
# 38 .  हमारे बीच व्यापार एवं निवेश के संबंध और अधिक प्रगाढ़ हो रहे हैं।
# 39 .  अंतरराष्‍ट्रीय योग दिवस के अवसर पर पूरे विश्‍व में योग से जुड़े अनेक आयोजन किये जा रहे हैं।
# 40 .  प्रधानमंत्री ने विस्‍तार से बताया कि केन्‍द्र सरकार ने ‘कारोबार में सुगमता बढ़ाने’ के साथ-साथ ‘देश के नागरिकों के लिए जीवन यापन में सहूलियत’ सुनिश्चित करने पर किस तरह से अपना ध्‍यान केन्द्रित कर रखा है।
# 41 .  सड़क, रेल एवं जलमार्गों की भारी आवश्यकता है।
# 42 .  बातचीत के दौरान चालक दल के महिला सदस्यों ने मिशन के विभिन्न आयामों जैसे तैयारी, प्रशिक्षण व यात्रा के दौरान अनुभव पर आधारित एक प्रस्तुति दी।
# 43 .  उत्कल विश्व-विद्यालय भुवनेश्वर में पाइका विद्रोह पर पीठ की स्थापना किये जाने की घोषणा की गयी।
# 44 .  प्रधानमंत्री ने उन्हें उनकी नई जिम्मेदारियों को सफलतापूर्वक निभाने के लिए भारत द्वारा पूर्ण और रचनात्मक सहयोग करने का आश्वासन दिया।
# 45 .  उन्होंने कहा कि अधिक से अधिक जल का सावधानीपूर्वक संरक्षण करना एक उत्तरदायित्व भी है।
# 46 .  उन्होंने संगठित प्रयासों से न सिर्फ़ अपना बल्कि अपने क्षेत्र का भी भाग्य बदल डाला।
# 47 .  उमंग एप के जरिए 100 से भी अधिक जनोपयोगी सेवाएं देश के नागरिकों को उनके मोबाइल फोन के जरिए उपलब्‍ध कराई गई हैं।
# 48 .  वास्‍तव में यह एक ऐस कार्य है जो हर आध्‍यात्मिक साधक, योगी और यहां तक कि आम आदमी को भी लाभ पहुंचा सकता है।
# 49 .  लेकिन ज्ञान आज भी हमारा सबसे अच्‍छा मार्गदर्शक है।
# 50 .  आज उद्घाटन होने वाला चरण अलुवा से पलारिवट्टम तक परिचालन करेगा।

# %%
for i,sent in enumerate(rand_50_guj):
    print(i+1,". ", sent)
# Out:
# 1 .  તેઓ સરકારની ઉપલબ્ધિઓ દર્શાવતા દસ્તાવેજ પ્રસિદ્ધ કરશે.
# 2 .  હું પ્રધાનમંત્રી આબેનો વ્યક્તિગત સ્તરે પ્રોત્સાહન અને સાથસહકાર આપવા બદલ વિશેષ આભારી છું.
# 3 .  આવતા બે મહિના આપણે બધા ચૂંટણીની દોડાદોડમાં વ્યસ્ત હોઇશું.
# 4 .  તેમણે કહ્યું હતું કે, કેન્દ્ર સરકારે ત્રણ વર્ષમાં 5 કરોડ શૌચાલયો બનાવ્યાં છે.
# 5 .  છઠ પૂજાનું અનુપમ પર્વ પ્રકૃતિથી અને પ્રકૃતિની ઉપાસના સાથે પૂરી રીતે જોડાયેલું છે.
# 6 .  કરાર કરનાર પક્ષકારો આ કરારમાં જરૂરી રાષ્ટ્રીય કાનૂની જરૂરિયાતો સંતોષવામાં આવી હોવા અંગે પોતાની ડિપ્લોમેટિક ચેનલો મારફતે નોટિફાય કરે તે પછી આ કરારને બીજા મહિનાના પ્રથમ દિવસથી અમલી બનાવવામાં આવશે.
# 7 .  હું મારા સાંસદો, પોતાનાં રાજ્યો અને જાપાનનાં પ્રાંતો વચ્ચે ગાઢ થઈ રહેલાં સંબંધોનું હૃદયપૂર્વક સ્વાગત કરું છું.
# 8 .  ભારત મધ ક્રાંતિ કરી રહ્યું છે.
# 9 .  માનવ સંસાધન વિકાસમાં સહાયતા અને સ્વાસ્થ્ય સુવિધાઓની સ્થાપના.
# 10 .  પ્રધાનમંત્રીએ ઉમેર્યું હતું કે, આ સુવિધાઓ પ્રવાસીઓને પણ આકર્ષશે.
# 11 .  વિશ્વ બેંકના વ્યાપાર-વાણિજ્ય માટે સરળતા માટેના 2018ના અહેવાલમાં ભારતે છેલ્લા ત્રણ વર્ષમાં 42 ક્રમની છલાંગ લગાવી છે અને હવે ભારત મોખરાના 100 દેશમાં આવી ગયો છે.
# 12 .  ગુજરાત અને મહારાષ્ટ્રના લોકો અને ખેડૂતો કે જેમને નર્મદા નદીનો લાભ મળ્યો છે તેમનો ઉલ્લેખ કરતા પ્રધાનમંત્રીએ મધ્ય પ્રદેશ સરકાર અને લોકોનો નર્મદા સેવા યાત્રા બદલ આભાર માન્યો હતો.
# 13 .  વીડિયો બ્રિજ દ્વારા પ્રધાનમંત્રીનો વિવિધ સરકારી યોજનાઓના લાભાર્થીઓ સાથે સંવાદની શ્રેણીનો આ પાંચમો વાર્તાલાપ છે.
# 14 .  આ કાર્યક્રમમાં બોલતાં તેમણે જણાવ્યું હતું કે, મહાત્મા ગાંધીનાં વિચારો દુનિયા હાલ જે પડકારોનો સામનો કરી રહી છે તેનું સમાધાન કરવાની તાકાત ધરાવે છે.
# 15 .  અત્યારે તેમની પાસે સ્માર્ટફોન છે અને નાણાકીય સેવાઓ પૂરી પાડવા ડિજિટલ ઉપકરણો છે.
# 16 .  આ વારસાને આપણે વધુ સશક્ત કરવાનો છે.
# 17 .  રાજસ્થાન જેવી મરુભૂમિમાં બિશ્નોઈ સમાજે પર્યાવરણ સંરક્ષણનો રસ્તો આપણને દેખાડ્યો છે.
# 18 .  એવું લાગે છે કે તે જાણે જીવન-મરણનો સવાલ હોય.
# 19 .  તે કેન્દ્ર સરકાર અને તમામ રાજ્ય સરકારો તેમજ તમામ રાજકીય પક્ષો વચ્ચે સહકારને કારણે શક્ય બન્યો છે.
# 20 .  આ સપ્તાહ ઉત્તરાખંડ અને હરિયાણા પણ ઓડીએફ જાહેર થઈ ચૂક્યા છે.
# 21 .  તેમણે વાઇબ્રન્ટ અને સમૃદ્ધ દેશ માટે સકારાત્મક સમાચારનાં મહત્વ પર ભાર મૂક્યો હતો.
# 22 .  વિજ્ઞાન અને ટેકનોલોજી
# 23 .  સૌથી વધુ ઝડપથી વિકસતાં અર્થતંત્રોની જેમ ભારતમાં પણ આપણા પડકારો પણ તમામ સ્તરે વધશે.
# 24 .  દેશ શાંતિ, એકતા અને સદભાવથી ચાલે છે.
# 25 .  અત્યાર સુધી આ પોર્ટલ પર 41 કાર્યક્રમો અને 20 મંત્રાલયોની યોજનાઓના ડેટાસેટનું સંકલન થયું છે.
# 26 .  પ્રધાનમંત્રીએ રેલવે સ્ટેશનોના પુર્નવિકાસ સાથે સંબંધિત કામગીરીની ઝડપ વધારવા અને ભાડા સિવાયની આવકમાં વધારે નવીન અભિગમ અપનાવવા જણાવ્યું હતું.
# 27 .  જાપાનના લોકોએ સ્થાયી વિકાસમાં દુનિયાની આગેવાની લીધી છે.
# 28 .  આપણા ખેલાડીઓએ ઉત્કૃષ્ટ પ્રદર્શન કર્યું અને તેના બળે ભારત દસ વર્ષ પછી એશિયા કપ ચેમ્પિયન બન્યું છે.
# 29 .  આ રુદ્રાક્ષ વારાણસી માટે જાપાનના પ્રેમનું પ્રતીક બનશે.
# 30 .  સામાન્ય રીતે તેમનું નિર્માણ જમીનના મોટા વિસ્તાર પર થયું હતું અને ઘણી વખત તેઓ રહેણાક વિસ્તારોથી દૂર હતા.
# 31 .  તેઓ એકલા જ કોઈ પણ આધુનિક ટૅક્નૉલૉજી વગર એક નાનકડી હોડી લઈને વિશ્વ ભ્રમણ કરનારા પહેલા ભારતીય હતા.
# 32 .  પ્રધાનમંત્રી નરેન્દ્ર મોદી ટેકનપુર, મધ્યપ્રદેશમાં બીએસએફ અકાદમી ખાતે આગામી 7મી અને 8મી જાન્યુઆરીએ ડીજીપી અને આઈજીપીની વાર્ષિક પરિષદમાં ભાગ લેશે.
# 33 .  પ્રધાનમંત્રીએ કહ્યું હતું કે, ભારતમાં આધ્યાત્મિક સંસ્થાઓ સામાજિક સુધારા માટેના કેન્દ્રો ધરાવે છે.
# 34 .  આ વર્ષના પ્રારંભે આ જોડાણની એક પરિષદ નવી દિલ્હીમાં મળી હતી.
# 35 .  તેઓ દિલ્લીમાં કર્ણાટકની આકાંક્ષાઓનો એક પ્રભાવશાળી અવાજ હતા.
# 36 .  તેમણે કહ્યું કે, પ્રવાસી ભારતીયોનાં પ્રયાસથી દુનિયામાં તમામ જગ્યાએ ભારતીય પાસપોર્ટ પ્રત્યે સન્માન સુનિશ્ચિત થયું છે.
# 37 .  મને ફરી એકવાર સીમા પર તહેનાત આપણા જાંબાઝ સુરક્ષાદળોની સાથે દિવાળી મનાવવાનું સૌભાગ્ય મળ્યું.
# 38 .  અમારી વચ્ચે વેપાર અને રોકાણના સંબંધો વધારે ગાઢ થઇ રહ્યા છે.
# 39 .  વિશ્વ યોગ દિવસની ઉજવણીના ભાગરૂપે યોગ સંબંધિત કાર્યક્રમો સમગ્ર વિશ્વમાં યોજવામાં આવી રહ્યા છે.
# 40 .  પ્રધાનમંત્રીએ સમજાવ્યુ હતું કે, તેમની સરકાર વેપાર-વાણિજ્યમાં સરળતા અને નાગરિકોના જીવનમાં સરળતા પર કેવી રીતે ધ્યાન કેન્દ્રિત કરી રહી છે.
# 41 .  રસ્તા, રેલવે અને દરિયાઈ માર્ગોની ખૂબ જરૂર છે.
# 42 .  આ મુલાકાત દરમિયાન મહિલા ખલાસીઓએ તેમના અભિયાનના વિવિધ પાસાઓ, તેની તૈયારી, તાલીમ અને અનુભવો વિશે રજૂઆત કરી હતી.
# 43 .  ભુવનેશ્વરમાં ઉત્કલ યુનિવર્સિટીમાં પાઇકા બળવા પર ચેર સ્થાપિત કરવાની જાહેરાત કરવામાં આવી હતી.
# 44 .  પ્રધાનમંત્રીએ તેમને તેમની નવી જવાબદારીનું વહન કરવામાં ભારતના સંપૂર્ણ અને રચનાત્મક સાથસહકારની ખાતરી આપી હતી.
# 45 .  તેમણે જણાવ્યું હતું કે, આપણી જવાબદારી પાણીનો કાળજીપૂર્વક ઉપયોગ કરવાની અને તેનું સંરક્ષણ કરવાની પણ છે.
# 46 .  તેમના સંગઠિત પ્રયાસોથી ન માત્ર તેમનું પોતાનું પરંતુ પોતાના ક્ષેત્રનું પણ ભાગ્ય બદલી નાખ્યું.
# 47 .  ઉમંગ એપ દ્વારા 100થી વધારે જાહેર સેવાના ક્ષેત્રો દેશવાસીઓને તેમના મોબાઈલ ફોન પર ઉપલબ્ધ છે.
# 48 .  હકીકતમાં આ વોલ્યુમ ખજાનો છે, જેનો લાભ અધ્યાત્મમાં રસ ધરાવતી દરેક વ્યક્તિ, યોગી અને સામાન્ય નાગરિક પણ લઈ શકે છે.
# 49 .  અત્યારે પણ જ્ઞાન, માહિતી કે જાણકારી દિવાદાંડીરૂપ છે.
# 50 .  આજે જે ફેઝનું ઉદ્ઘાટન થયું છે, એ અલુવાથી પલારિવટ્ટમ સુધી ઓપરેટ થશે.

# %%
# saving these 50 sentences from each langauge for using in evaluation part
write_to_file('/kaggle/working/eng_50_for_ChatGPT.txt', rand_50_eng)
write_to_file('/kaggle/working/hin_50_for_ChatGPT.txt', rand_50_hin)
write_to_file('/kaggle/working/guj_50_for_ChatGPT.txt', rand_50_guj)
